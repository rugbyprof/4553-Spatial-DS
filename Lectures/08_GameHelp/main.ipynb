# %%
import geopandas
import folium
import json
from rich import print
from shapely.geometry import box, Polygon, LineString, Point

# %%
# Out:
# [
#     [-122.87109375, -62.91523303947613],
#     [-29.53125, -62.91523303947613],
#     [-29.53125, 35.17380831799959],
#     [-122.87109375, 35.17380831799959],
#     [-122.87109375, -62.91523303947613]
# ]
# (-122.87109375, -62.91523303947613, -29.53125, 35.17380831799959)

# %%
# create a map and give it a center and initial zoom
m1 = folium.Map(location=[50, 50], zoom_start=3)

# add the geojson of europe.
# remember it must be valid geojson!
folium.GeoJson(southam, name="geojson").add_to(m1)
folium.GeoJson(northam, name="geojson").add_to(m1)

# add the layer control (zoom in and out buttons)
folium.LayerControl().add_to(m1)
m1
m1.save("01_geojson_map.html")

# %%
# s = geopandas.GeoSeries(polygons)
# s.append(bbox)
# Out:
# 55
# [
#     [
#         [-68.6541235, -54.8862444],
#         [-68.65413543, -54.88624456],
#         [-68.65413512, -54.88624371],
#         [-68.6423429, -54.85365326],
#         [-68.6419876, -54.79917412],
#         [-68.63231361, -54.80535247],
#         [-68.60936439, -54.83228932],
#         [-68.59947669, -54.8414039],
#         [-68.58055579, -54.85475026],
#         [-68.57184811, -54.86272552],
#         [-68.56822669, -54.87835052],
#         [-68.58726966, -54.88534922],
#         [-68.6541235, -54.8862444]
#     ]
# ]
# [-68.6541235, -54.8862444]
# [
#     [
#         [-64.34056556, -54.715997],
#         [-64.32371986, -54.72226328],
#         [-64.30553138, -54.7155901],
#         [-64.30064857, -54.72079843],
#         [-64.29625404, -54.72210052],
#         [-64.29137122, -54.72210052],
#         [-64.28506426, -54.72307708],
#         [-64.27155514, -54.72722747],
#         [-64.24136308, -54.721775],
#         [-64.22423255, -54.72307708],
# ...
