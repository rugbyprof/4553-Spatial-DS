# %%
import osmnx as ox
G = ox.graph_from_place('Wichita County', network_type='drive')
ox.plot_graph(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/osmnx/core.py:661: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# (<Figure size 687.021x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f838eaa5550>)

# %%
print("node count:", len(G.nodes()))
print("edge count:", len(G.edges()))
# Out:
# node count: 8685
# edge count: 23409
